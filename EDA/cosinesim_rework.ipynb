# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
hike_data = pd.read_csv('data/clean_hike_data.csv', index_col=0)

# %%
hike_data.head()
# Out:
#                       HikeName            Region         Subregion  \
# 0  Dirty Face Lookout and Peak  Central Cascades  Central Cascades
# 1                  Perry Creek    North Cascades    North Cascades
# 2       Hannegan Pass and Peak    North Cascades    North Cascades
# 3               Eruption Trail    South Cascades    South Cascades
# 4            Copper Ridge Loop    North Cascades    North Cascades
#
#            TotalDistance ElevationGain MaximumElevation  \
# 0   9.0 miles, roundtrip          3950             5989
# 1  10.5 miles, roundtrip          3400             5250
# 2  10.4 miles, roundtrip          3100             6200
# 3   0.5 miles, roundtrip            25             4200
# 4  34.0 miles, roundtrip          8600             6260
#
#                                          Description             PassNeeded  \
# 0  Dirty Face Lookout is one of the earliest high...  Northwest Forest Pass
# 1  Perry Creek proves you can have it all, and yo...  Northwest Forest Pass
# 2  Begin hiking from the parking area at the end ...  Northwest Forest Pass
# 3  A barrier-free, paved hike of less than one mi...  National Monument Fee
# 4  Experience the variety offered by the North Ca...  Northwest Forest Pass
#
#              LatLong  TimeFromSeattle  ...  Rivers  Summits  Waterfalls  \
# 0  47.8379,-120.7976       125.600000  ...       0        1           0
# 1  48.0541,-121.4907        93.083333  ...       0        1           1
# 2  48.9101,-121.5927       163.533333  ...       0        1           0
# 3  46.2765,-122.2165       161.750000  ...       0        0           0
# 4  48.9102,-121.5917       163.800000  ...       1        1           0
#
#    WildflowersMeadows  Wildlife  \
# 0                   1         0
# 1                   1         0
# 2                   0         1
# 3                   1         0
# 4                   0         1
#
#                                                  Url  Rating  NumVotes  \
# 0  https://www.wta.org/go-hiking/hikes/dirtyface-...    3.82        17
# 1    https://www.wta.org/go-hiking/hikes/perry-creek    4.28        29
# 2  https://www.wta.org/go-hiking/hikes/hannegan-p...    4.35        23
# 3  https://www.wta.org/go-hiking/hikes/eruption-t...    3.00         5
# 4  https://www.wta.org/go-hiking/hikes/copper-rid...    4.36        11
#
#    countTripReports  distance
# 0               217       9.0
# 1               617      10.5
# 2               512      10.4
# 3                18       0.5
# 4               122      34.0
#
# [5 rows x 29 columns]

# %%
def norm(df, col):
    """Normalized the give column of the provided dataframe"""
    df[col] = pd.to_numeric(df[col],errors='coerce')
    df[f"{col}_normalized"] = (df[col] - df[col].mean())/(df[col].max() - df[col].min())

# %%
norm(hike_data, 'ElevationGain')
norm(hike_data, 'TimeFromSeattle')
norm(hike_data, 'countTripReports')
norm(hike_data, 'distance')

# %%
hike_data.replace(to_replace=["None"], value=np.nan, inplace=True)
hike_data.fillna(0, inplace=True)

# %%
hike_data[hike_data['HikeName']=="Dirty Harry's Balcony"]
# Out:
#                  HikeName             Region          Subregion  \
# 52  Dirty Harry's Balcony  Snoqualmie Region  Snoqualmie Region
#
#            TotalDistance  ElevationGain MaximumElevation  \
# 52  4.4 miles, roundtrip         1300.0             2600
#
#                                           Description     PassNeeded  \
# 52  Get a workout and marvel at rock work complete...  Discover Pass
#
#               LatLong  TimeFromSeattle  ...  Wildlife  \
# 52  47.4312,-121.6324        39.866667  ...         1
#
#                                                   Url  Rating  NumVotes  \
# 52  https://www.wta.org/go-hiking/hikes/dirty-harr...    3.47        45
#
#     countTripReports  distance  ElevationGain_normalized  \
# 52               702       4.4                 -0.024958
#
#     TimeFromSeattle_normalized  countTripReports_normalized  \
# 52                   -0.235166                     0.252308
#
#     distance_normalized
# 52            -0.002338
#
# [1 rows x 33 columns]

# %%
hike_data.columns
# Out:
# Index(['HikeName', 'Region', 'Subregion', 'TotalDistance', 'ElevationGain',
#        'MaximumElevation', 'Description', 'PassNeeded', 'LatLong',
#        'TimeFromSeattle', 'Coast', 'DogsAllowed', 'EstablishedCampsites',
#        'FallFoliage', 'GoodForKids', 'Lakes', 'MountainViews', 'OldGrowth',
#        'RidgesPasses', 'Rivers', 'Summits', 'Waterfalls', 'WildflowersMeadows',
#        'Wildlife', 'Url', 'Rating', 'NumVotes', 'countTripReports', 'distance',
#        'ElevationGain_normalized', 'TimeFromSeattle_normalized',
#        'countTripReports_normalized', 'distance_normalized'],
#       dtype='object')

# %%
recommender_cols = ['Coast', 'DogsAllowed', 'EstablishedCampsites',
       'FallFoliage', 'GoodForKids', 'Lakes', 'MountainViews', 'OldGrowth',
       'RidgesPasses', 'Rivers', 'Summits', 'Waterfalls', 'WildflowersMeadows',
       'Wildlife', 
       'ElevationGain_normalized', 'TimeFromSeattle_normalized',
       'countTripReports_normalized', 'distance_normalized']

# %%
rec_test_data = hike_data[recommender_cols]

# %%
rec_test_data['hike_id'] = rec_test_data.index
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
"""DOC strings"""

# import packages
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity



class hikeRecommender(object):

    def __init__(self, hikes, weights=None):
        self.hike_matrix = hikes
        self.feature_weights = weights
        self.hikes_liked = pd.DataFrame(columns=hikes.columns)
        self.hikes_disliked = pd.DataFrame(columns=hikes.columns)
        if not weights:
            self.weights={c:1 for c in hikes.columns}
        else: 
            self.weights=weights
            self.weighted_hike_matrix = self.apply_weights()

    def like_hike(self, hike_id):
        indx = self.hike_matrix[self.hike_matrix['hike_id']==hike_id].index[0]
        self.hikes_liked = self.hikes_liked.append(self.hike_matrix.iloc[indx])
        self.hike_matrix = self.hike_matrix.drop(indx, axis=0).reset_index(drop=True)

    def recommend(self, n=5, apply_weights=True):
        # Calculate similarity to all of the hikes
        # average similarities
        # return top 5
        indx_id = self.hike_matrix['hike_id']
        X = self.hike_matrix.drop('hike_id', axis=1)
        y = self.hikes_liked.drop('hike_id', axis=1)
        cs = cosine_similarity(X, y).mean(axis=1)
        rec_index= np.argsort(cs)[-n:][::-1]
        recommendations = indx_id.iloc[rec_index]
        return recommendations
        
    def apply_weights(self):
        weighted_hike_matrix = pd.DataFrame(columns=self.hike_matrix.columns)
        for col, weight in self.weights.items():
            weighted_hike_matrix[col] = self.hike_matrix[col].apply(lambda x: x*weight) 
        return weighted_hike_matrix

# %%
# import weights
import json
with open('data/weights.json', 'r') as weights_fp:
    weight = json.load(weights_fp)

# %%
weight
# Out:
# {'ElevationGain': 0.08088926374096386,
#  'TimeFromSeattle': 0.15267880383054017,
#  'Coast': 0.002390998999926175,
#  'DogsAllowed': 0.0012553190403816,
#  'EstablishedCampsites': 0.01015433268815869,
#  'FallFoliage': 0.03621965292388979,
#  'GoodForKids': 0.0,
#  'Lakes': 0.008223032157539938,
#  'MountainViews': 0.018512043506946005,
#  'OldGrowth': 0.025258605813801176,
#  'RidgesPasses': 0.004037668934122245,
#  'Rivers': 0.007060788267084692,
#  'Summits': 0.010542753598486509,
#  'Waterfalls': 0.00019599592911147094,
#  'WildflowersMeadows': 0.002537626643713041,
#  'Wildlife': 0.017885814526906914,
#  'countTripReports': 0.5443232877124791,
#  'distance': 0.07783401168594875}

# %%
weight = {'ElevationGain_normalized': 0.2088926374096386,
 'TimeFromSeattle_normalized': 0.5267880383054017,
 'Coast': 0.002390998999926175,
 'DogsAllowed': 0.0012553190403816,
 'EstablishedCampsites': 0.01015433268815869,
 'FallFoliage': 0.03621965292388979,
 'GoodForKids': 0.0,
 'Lakes': 0.008223032157539938,
 'MountainViews': 0.018512043506946005,
 'OldGrowth': 0.025258605813801176,
 'RidgesPasses': 0.004037668934122245,
 'Rivers': 0.007060788267084692,
 'Summits': 0.010542753598486509,
 'Waterfalls': 0.00019599592911147094,
 'WildflowersMeadows': 0.002537626643713041,
 'Wildlife': 0.017885814526906914,
 'countTripReports_normalized': 0.5443232877124791,
 'distance_normalized': 0.07783401168594875}

# %%
hr=hikeRecommender(rec_test_data, weights=weight)

# %%
hike_data[hike_data['HikeName'].str.contains("Mount Townsend")]
# Out:
#                                     HikeName             Region  \
# 1124                          Mount Townsend  Olympic Peninsula
# 1125  Mount Townsend - Silver Lakes Traverse  Olympic Peninsula
# 3707                 Mount Townsend Snowshoe  Olympic Peninsula
#
#               Subregion          TotalDistance  ElevationGain  \
# 1124  Olympic Peninsula   8.0 miles, roundtrip         3010.0
# 1125  Olympic Peninsula  14.0 miles, roundtrip         3200.0
# 3707  Olympic Peninsula  13.5 miles, roundtrip         2500.0
#
#      MaximumElevation                                        Description  \
# 1124             6260  Is Mount Townsend popular because there are fo...
# 1125             6280  Who doesn’t love a secret passageway? While th...
# 3707             5500                                                  0
#
#      PassNeeded            LatLong  TimeFromSeattle  ...  Wildlife  \
# 1124          0  47.8564,-123.0359       152.233333  ...         0
# 1125          0  47.8576,-123.0946       199.966667  ...         0
# 3707          0  47.8559,-123.0360       152.250000  ...         0
#
#                                                     Url  Rating  NumVotes  \
# 1124  https://www.wta.org/go-hiking/hikes/mount-town...    4.26        53
# 1125  https://www.wta.org/go-hiking/hikes/mount-town...    4.00         4
# 3707  https://www.wta.org/go-hiking/hikes/mount-town...    1.00         2
#
#       countTripReports  distance  ElevationGain_normalized  \
# 1124               992       8.0                  0.036133
# 1125                62      14.0                  0.042921
# 3707                27      13.5                  0.017913
#
#       TimeFromSeattle_normalized  countTripReports_normalized  \
# 1124                    0.024561                     0.368262
# 1125                    0.134893                    -0.003590
# 3707                    0.024600                    -0.017584
#
#       distance_normalized
# 1124            -0.000837
# 1125             0.001663
# 3707             0.001454
#
# [3 rows x 33 columns]

# %%
mailbox = 121
townsend = 1124

# %%
hr.like_hike(mailbox)

# %%
hr.like_hike(townsend)

# %%
recs = hike_data.iloc[list(hr.recommend(10))]

# %%
recs[['HikeName', 'Region', 'TotalDistance', 'ElevationGain',
       'TimeFromSeattle', 'countTripReports']].sort_values('countTripReports', ascending=True)
# Out:
#                                HikeName                Region  \
# 1619                      Cornell Butte    Eastern Washington
# 1738                     Summit Springs        South Cascades
# 660   West Tiger No. 1 via Dwight's Way         Issaquah Alps
# 1331      Phils Trail - Thrush Gap Loop         Issaquah Alps
# 1700                       Grassy Knoll  Southwest Washington
# 728                        Sunrise Peak        South Cascades
# 2447          South Tiger Mountain Loop         Issaquah Alps
# 648       Thorp Mountain via Knox Creek     Snoqualmie Region
# 714                      Carne Mountain      Central Cascades
# 406                    Granite Mountain     Snoqualmie Region
#
#               TotalDistance  ElevationGain  TimeFromSeattle  countTripReports
# 1619  3.25 miles, roundtrip          600.0       316.616667                 1
# 1738   5.6 miles, roundtrip         1738.0         0.000000                10
# 660    8.0 miles, roundtrip         2500.0        20.483333                21
# 1331   8.2 miles, roundtrip         1606.0        29.000000                30
# 1700   4.4 miles, roundtrip         1048.0       255.066667                33
# 728    3.0 miles, roundtrip         1400.0       181.300000                42
# 2447   8.6 miles, roundtrip         1550.0        32.533333                60
# 648    4.4 miles, roundtrip         1734.0       118.283333                99
# 714    7.3 miles, roundtrip         3600.0       186.483333               213
# 406    8.6 miles, roundtrip         3800.0        46.433333              1818
