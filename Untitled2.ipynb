# %%
from recommender import itemContentRecommender
import pandas as pd
import cPickle as pickle

with open('pickle/ic_recommender.pkl', 'r') as f:
    model = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-73f727a1c5f9> in <module>()
# ----> 1 from recommender import itemContentRecommender
#       2 import pandas as pd
#       3 import cPickle as pickle
#
# ImportError: No module named recommender
